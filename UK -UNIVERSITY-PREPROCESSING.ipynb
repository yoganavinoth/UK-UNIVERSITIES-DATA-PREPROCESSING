# %%
import pandas as pd

# %%
dataset=pd.read_csv("uk_universities.csv")
dataset
# Out:
#                     University_name              Region  Founded_year  \
# 0           University of Cambridge     East of England          1209
# 1              University of Oxford  South East England          1096
# 2          University of St Andrews            Scotland          1413
# 3           Imperial College London              London          1907
# 4           Loughborough University       East Midlands          1966
# ..                              ...                 ...           ...
# 126       University of East London              London          1992
# 127      University of Bedfordshire     East of England          2006
# 128           University of Suffolk     East of England          2007
# 129      Wrexham Glyndwr University               Wales          2008
# 130  Ravensbourne University London              London          1962
#
#                                                  Motto  UK_rank  World_rank  \
# ...

# %%
dataset.isnull().sum()
# Out:
# University_name                                   0
# Region                                            0
# Founded_year                                      0
# Motto                                            17
# UK_rank                                           0
# World_rank                                        0
# CWUR_score                                       47
# Minimum_IELTS_score                               0
# UG_average_fees_(in_pounds)                       0
# PG_average_fees_(in_pounds)                       0
# International_students                            0
# Student_satisfaction                              0
# Student_enrollment                                0
# Academic_staff                                    0
# Control_type                                      0
# Academic_Calender                                26
# Campus_setting                                   18
# Estimated_cost_of_living_per_year_(in_pounds)     0
# ...

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
    #print(columnName)
        if(dataset[columnName].dtypes=='O'):
        #print("qual")
            qual.append(columnName)
        else:
        #print("quan")
             quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(dataset)

# %%
quan
# Out:
# ['Founded_year',
#  'UK_rank',
#  'World_rank',
#  'CWUR_score',
#  'Minimum_IELTS_score',
#  'UG_average_fees_(in_pounds)',
#  'PG_average_fees_(in_pounds)',
#  'Estimated_cost_of_living_per_year_(in_pounds)',
#  'Latitude',
#  'Longitude']

# %%
qual
# Out:
# ['University_name',
#  'Region',
#  'Motto',
#  'International_students',
#  'Student_satisfaction',
#  'Student_enrollment',
#  'Academic_staff',
#  'Control_type',
#  'Academic_Calender',
#  'Campus_setting',
#  'Website']

# %%
dataset[quan]
# Out:
#      Founded_year  UK_rank  World_rank  CWUR_score  Minimum_IELTS_score  \
# 0            1209        1           4        94.1                  6.5
# 1            1096        2           2        93.3                  6.5
# 2            1413        3          86        75.8                  6.5
# 3            1907        4           8        86.6                  6.5
# 4            1966        5         404        72.8                  5.5
# ..            ...      ...         ...         ...                  ...
# 126          1992      127         971         NaN                  4.5
# 127          2006      128        1281         NaN                  4.5
# 128          2007      129        4030         NaN                  4.5
# 129          2008      130        2397         NaN                  4.5
# 130          1962      131        2759         NaN                  5.5
#
#      UG_average_fees_(in_pounds)  PG_average_fees_(in_pounds)  \
# ...

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy="mean",verbose=0,copy=True)
imp.fit(dataset[quan])
datan=imp.transform(dataset[quan])

# %%
imp
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='mean', verbose=0)

# %%
datan
# Out:
# array([[ 1.20900e+03,  1.00000e+00,  4.00000e+00, ...,  1.20000e+04,
#          5.22054e+01,  1.13200e-01],
#        [ 1.09600e+03,  2.00000e+00,  2.00000e+00, ...,  1.15000e+04,
#          5.17548e+01, -1.25440e+00],
#        [ 1.41300e+03,  3.00000e+00,  8.60000e+01, ...,  1.20000e+04,
#          5.63417e+01, -2.79430e+00],
#        ...,
#        [ 2.00700e+03,  1.29000e+02,  4.03000e+03, ...,  9.41500e+03,
#          5.20523e+01,  1.16290e+00],
#        [ 2.00800e+03,  1.30000e+02,  2.39700e+03, ...,  7.77100e+03,
#          5.30526e+01, -3.00620e+00],
#        [ 1.96200e+03,  1.31000e+02,  2.75900e+03, ...,  1.02290e+04,
#          5.15017e+01,  5.50000e-03]])

# %%
datan=pd.DataFrame(datan,columns=quan)

# %%
datan
# Out:
#      Founded_year  UK_rank  World_rank  CWUR_score  Minimum_IELTS_score  \
# 0          1209.0      1.0         4.0   94.100000                  6.5
# 1          1096.0      2.0         2.0   93.300000                  6.5
# 2          1413.0      3.0        86.0   75.800000                  6.5
# 3          1907.0      4.0         8.0   86.600000                  6.5
# 4          1966.0      5.0       404.0   72.800000                  5.5
# ..            ...      ...         ...         ...                  ...
# 126        1992.0    127.0       971.0   73.960714                  4.5
# 127        2006.0    128.0      1281.0   73.960714                  4.5
# 128        2007.0    129.0      4030.0   73.960714                  4.5
# 129        2008.0    130.0      2397.0   73.960714                  4.5
# 130        1962.0    131.0      2759.0   73.960714                  5.5
#
#      UG_average_fees_(in_pounds)  PG_average_fees_(in_pounds)  \
# ...

# %%
dataset[qual]
# Out:
#                     University_name              Region  \
# 0           University of Cambridge     East of England
# 1              University of Oxford  South East England
# 2          University of St Andrews            Scotland
# 3           Imperial College London              London
# 4           Loughborough University       East Midlands
# ..                              ...                 ...
# 126       University of East London              London
# 127      University of Bedfordshire     East of England
# 128           University of Suffolk     East of England
# 129      Wrexham Glyndwr University               Wales
# 130  Ravensbourne University London              London
#
#                                                  Motto International_students  \
# 0                 From here, light and sacred draughts                 20.20%
# 1                                 The Lord is my light                 16.80%
# ...

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy="most_frequent")
imp.fit(dataset[qual])
datal=imp.transform(dataset[qual])

# %%
imp
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='most_frequent', verbose=0)

# %%
datal
# Out:
# array([['University of Cambridge', 'East of England',
#         'From here, light and sacred draughts', ..., 'Trimesters',
#         'Urban', 'www.cam.ac.uk'],
#        ['University of Oxford', 'South East England',
#         'The Lord is my light', ..., 'Trimesters', 'Urban',
#         'www.ox.ac.uk'],
#        ['University of St Andrews', 'Scotland', 'Ever to excel', ...,
#         'Semesters', 'Suburban', 'www.st-andrews.ac.uk'],
#        ...,
#        ['University of Suffolk', 'East of England',
#         'Honesty and diligence', ..., 'Semesters', 'Urban',
#         'www.ucs.ac.uk/'],
#        ['Wrexham Glyndwr University', 'Wales',
#         'Confidence through Education', ..., 'Semesters', 'Urban',
#         'www.glyndwr.ac.uk/'],
#        ['Ravensbourne University London', 'London',
#         'Designed for industry', ..., 'Semesters', 'Urban',
#         'www.ravensbourne.ac.uk']], dtype=object)

# %%
datal=pd.DataFrame(datal,columns=qual)

# %%
datal
# Out:
#                     University_name              Region  \
# 0           University of Cambridge     East of England
# 1              University of Oxford  South East England
# 2          University of St Andrews            Scotland
# 3           Imperial College London              London
# 4           Loughborough University       East Midlands
# ..                              ...                 ...
# 126       University of East London              London
# 127      University of Bedfordshire     East of England
# 128           University of Suffolk     East of England
# 129      Wrexham Glyndwr University               Wales
# 130  Ravensbourne University London              London
#
#                                                  Motto International_students  \
# 0                 From here, light and sacred draughts                 20.20%
# 1                                 The Lord is my light                 16.80%
# ...

# %%
dataset=pd.read_csv("uk_universities.csv")

# %%
dataset
# Out:
#                     University_name              Region  Founded_year  \
# 0           University of Cambridge     East of England          1209
# 1              University of Oxford  South East England          1096
# 2          University of St Andrews            Scotland          1413
# 3           Imperial College London              London          1907
# 4           Loughborough University       East Midlands          1966
# ..                              ...                 ...           ...
# 126       University of East London              London          1992
# 127      University of Bedfordshire     East of England          2006
# 128           University of Suffolk     East of England          2007
# 129      Wrexham Glyndwr University               Wales          2008
# 130  Ravensbourne University London              London          1962
#
#                                                  Motto  UK_rank  World_rank  \
# ...

# %%
dataset=pd.concat([datan,datal],axis=1)

# %%
dataset
# Out:
#      Founded_year  UK_rank  World_rank  CWUR_score  Minimum_IELTS_score  \
# 0          1209.0      1.0         4.0   94.100000                  6.5
# 1          1096.0      2.0         2.0   93.300000                  6.5
# 2          1413.0      3.0        86.0   75.800000                  6.5
# 3          1907.0      4.0         8.0   86.600000                  6.5
# 4          1966.0      5.0       404.0   72.800000                  5.5
# ..            ...      ...         ...         ...                  ...
# 126        1992.0    127.0       971.0   73.960714                  4.5
# 127        2006.0    128.0      1281.0   73.960714                  4.5
# 128        2007.0    129.0      4030.0   73.960714                  4.5
# 129        2008.0    130.0      2397.0   73.960714                  4.5
# 130        1962.0    131.0      2759.0   73.960714                  5.5
#
#      UG_average_fees_(in_pounds)  PG_average_fees_(in_pounds)  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Founded_year                                     0
# UK_rank                                          0
# World_rank                                       0
# CWUR_score                                       0
# Minimum_IELTS_score                              0
# UG_average_fees_(in_pounds)                      0
# PG_average_fees_(in_pounds)                      0
# Estimated_cost_of_living_per_year_(in_pounds)    0
# Latitude                                         0
# Longitude                                        0
# University_name                                  0
# Region                                           0
# Motto                                            0
# International_students                           0
# Student_satisfaction                             0
# Student_enrollment                               0
# Academic_staff                                   0
# Control_type                                     0
# ...

# %%
csv=dataset.to_csv("preprocessed ckd.csv",index=False)
